# %% [markdown]
# # Dokumentacia riesenia

# %% [markdown]
# Architektura nasej neuronovej siete odovzdanej v prvom kontrolnom bode je nasledovna:

# %%
from IPython.display import Image
Image("images/NN_architecture.png")

# %% [markdown]
# Na vstupe mame dataset s atributmi USER_ID, JOKE_ID a Rating.
# 1. Z datasetu extrahujeme hodnoty USER_ID (teda ID roznych pouzivatelov, ktori ohodnotili vtipy) ako `user_input` a analogicky JOKE_ID ako `joke_input`.
# 2. Obe polia zakodujeme pouzitim one hot encodingu
# 3. Spojime dva zakodovane vektory do jedneho, co je vstupom nasej siete
# 4. Vytvorime embedding maticu spojeneho vektora
# 5. Embedding transformujeme do jednorozmerneho vektora
# 6. Pouzijeme 3 plne prepojene skryte vrstvy s aktivacnou funkciou relu. Pocet neuronov je v tomto momente 32,16 a 12
# 7. Vysledok poslednej plne prepojenej vrstvy ide do vrsty Dropout
# 8. Ako vystup mame taktiez plne prepojenu vrstvu s 10 neuronmi a aktivacnou funkciou tanh
#
# Ako stratovu funkciu (angl. loss function) pouzivame `mean square error` a ako optimilizator `Adam`.
